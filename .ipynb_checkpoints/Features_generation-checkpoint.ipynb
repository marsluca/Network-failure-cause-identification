# %% [markdown]
# <a href="https://colab.research.google.com/github/Patatone/Network-failure-cause-identification/blob/main/Failure_cause_identification_with_different_failures_location_IPY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import platform 

from pathlib import Path
plt.rcParams.update({'figure.max_open_warning': 0})

# %%
without_failure = ["Scenario_0", 
                   "Scenario_2_monitor_node_1_preamp_lpth_3-2_1", 
                   "Scenario_3_monitor_node_1_preamp_lpth_3-1_1", 
                   "Scenario_3_monitor_node_1_preamp_lpth_3-2_1"]

filtering_failure = ["Scenario_6_monitor_node_1_preamp_lpth_3-2_1",
                     "Scenario_7_monitor_node_1_preamp_lpth_2_1",
                     "Scenario_7_monitor_node_1_preamp_lpth_3-1_1", 
                     "Scenario_7_monitor_node_1_preamp_lpth_3-2_1",
                     "Scenario_8_monitor_node_1_preamp_lpth_3-1_1", 
                     "Scenario_8_monitor_node_1_preamp_lpth_3-2_1",
                     "Scenario_8_monitor_node_1_preamp_lpth_2_1"]

def norm_list(list_to_norm):
    return (list_to_norm-list_to_norm.mean())/list_to_norm.std()

def plot_scenario(file_name):
# Input: - file_name: name of the raw data file with OSNR values to be plotted
# Output: - plots of OSNR; figure should be saved into a subfolder ("Figures")

    scenario=file_name[9]
    lightpath=file_name.replace("Scenario_"+scenario+"_monitor_node_1_preamp_lpth_","").replace(".dat","")
    print('Plotting OSNR for scenario {}, lightpath {}'.format(scenario, lightpath))
    fig_folder = 'Figures' 
    if not os.path.exists(fig_folder):
        os.makedirs(fig_folder)
    
    data_raw = pd.read_csv(file_path + file_name.split("_monitor")[0] + '/' + file_name, skiprows = 5)
    
    print('Number of OSNR samples before: ' + str(len(data_raw)))
    
    # Drop duplicated rows with same DATE feature
    data_raw = data_raw.drop_duplicates(subset=[data_raw.columns.values[0]])

    # Keep only the last column
    OSNR_list = data_raw.iloc[:, -1].to_numpy(dtype='float')
    
    # Create a normalized version
    OSNR_list_norm=norm_list(OSNR_list)

    num_samples = len(OSNR_list)
    print('Number of OSNR samples: ' + str(num_samples))

    fig, axs = plt.subplots(1, 2, figsize=(15,8))
    
    global without_failure
    global filtering_failure
    
    if any(s in path.name for s in without_failure):
        color = (0, 143/255, 122/255)
    elif any(s in path.name for s in filtering_failure):
        color = (255/255, 199/255, 95/255)
    else:
        color = (195/255, 74/255, 54/255)
        
    axs[0].plot(OSNR_list, label = lightpath, color = color)
    axs[0].set_title('Raw Scenario: {}, Lightpath: {}'.format(scenario, lightpath))
    axs[0].set_xlabel('Samples, s')
    axs[0].set_ylabel('OSNR, dB')
    axs[0].grid()
    
    axs[1].plot(OSNR_list_norm, label = lightpath, color = color)
    axs[1].set_title('Norm. Scenario: {}, Lightpath: {}'.format(scenario, lightpath))
    axs[1].set_xlabel('Samples, s')
    axs[1].set_ylabel('OSNR, dB')
    axs[1].grid()
    
    fig.savefig(fig_folder + '/' + file_name.replace('.dat', '_raw_norm.png'))

# %%
###########################################################################################
###### Plot the OSNR figures for all scenarios
###########################################################################################

# Switch between Local and Colab execution
if platform.system() == 'Linux':
    from google.colab import drive
    drive.mount('/content/drive')
    file_path = '/content/drive/MyDrive/Colab Notebooks/NDAL_data/'
else:
    file_path = 'NDAL_data/'

for path in Path(file_path).rglob('*_preamp_lpth_*.dat'):
    print(path.name)
    plot_scenario(path.name)
    print()
# Out:
# Scenario_0_monitor_node_1_preamp_lpth_2_1.dat
# Plotting OSNR for scenario 0, lightpath 2_1
# Number of OSNR samples before: 21600
# Number of OSNR samples: 21600
#
# Scenario_0_monitor_node_1_preamp_lpth_3-1_1.dat
# Plotting OSNR for scenario 0, lightpath 3-1_1
# Number of OSNR samples before: 21600
# Number of OSNR samples: 21600
#
# Scenario_0_monitor_node_1_preamp_lpth_3-2_1.dat
# Plotting OSNR for scenario 0, lightpath 3-2_1
# Number of OSNR samples before: 21600
# Number of OSNR samples: 21600
#
# Scenario_1_monitor_node_1_preamp_lpth_2_1.dat
# Plotting OSNR for scenario 1, lightpath 2_1
# Number of OSNR samples before: 21600
# Number of OSNR samples: 21600
#
# Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat
# Plotting OSNR for scenario 1, lightpath 3-1_1
# Number of OSNR samples before: 21600
# Number of OSNR samples: 21600
#
# Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat
# Plotting OSNR for scenario 1, lightpath 3-2_1
# Number of OSNR samples before: 21600
# Number of OSNR samples: 21600
#
# Scenario_2_monitor_node_1_preamp_lpth_2_1.dat
# Plotting OSNR for scenario 2, lightpath 2_1
# Number of OSNR samples before: 21600
# Number of OSNR samples: 21600
#
# Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat
# Plotting OSNR for scenario 2, lightpath 3-1_1
# Number of OSNR samples before: 21600
# Number of OSNR samples: 21600
#
# Scenario_2_monitor_node_1_preamp_lpth_3-2_1.dat
# Plotting OSNR for scenario 2, lightpath 3-2_1
# Number of OSNR samples before: 21600
# Number of OSNR samples: 21599
#
# Scenario_3_monitor_node_1_preamp_lpth_2_1.dat
# Plotting OSNR for scenario 3, lightpath 2_1
# Number of OSNR samples before: 21600
# Number of OSNR samples: 21600
#
# Scenario_3_monitor_node_1_preamp_lpth_3-1_1.dat
# Plotting OSNR for scenario 3, lightpath 3-1_1
# Number of OSNR samples before: 21600
# Number of OSNR samples: 21600
#
# Scenario_3_monitor_node_1_preamp_lpth_3-2_1.dat
# Plotting OSNR for scenario 3, lightpath 3-2_1
# Number of OSNR samples before: 21600
# Number of OSNR samples: 21600
#
# Scenario_4_monitor_node_1_preamp_lpth_2_1.dat
# Plotting OSNR for scenario 4, lightpath 2_1
# Number of OSNR samples before: 21600
# Number of OSNR samples: 21600
#
# Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat
# Plotting OSNR for scenario 4, lightpath 3-1_1
# Number of OSNR samples before: 21600
# Number of OSNR samples: 21600
#
# Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat
# Plotting OSNR for scenario 4, lightpath 3-2_1
# Number of OSNR samples before: 21600
# Number of OSNR samples: 21600
#
# Scenario_5_monitor_node_1_preamp_lpth_2_1.dat
# Plotting OSNR for scenario 5, lightpath 2_1
# Number of OSNR samples before: 21600
# Number of OSNR samples: 21600
#
# Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat
# Plotting OSNR for scenario 5, lightpath 3-1_1
# Number of OSNR samples before: 21600
# Number of OSNR samples: 21599
#
# Scenario_5_monitor_node_1_preamp_lpth_3-2_1.dat
# Plotting OSNR for scenario 5, lightpath 3-2_1
# Number of OSNR samples before: 21600
# Number of OSNR samples: 21599
#
# Scenario_6_monitor_node_1_preamp_lpth_3-2_1_100GHz.dat
# Plotting OSNR for scenario 6, lightpath 3-2_1_100GHz
# Number of OSNR samples before: 600
# Number of OSNR samples: 600
#
# Scenario_6_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat
# Plotting OSNR for scenario 6, lightpath 3-2_1_12.5GHz
# Number of OSNR samples before: 300
# Number of OSNR samples: 300
#
# Scenario_6_monitor_node_1_preamp_lpth_3-2_1_25GHz.dat
# Plotting OSNR for scenario 6, lightpath 3-2_1_25GHz
# Number of OSNR samples before: 300
# Number of OSNR samples: 300
#
# Scenario_7_monitor_node_1_preamp_lpth_2_1_12.5GHz.dat
# Plotting OSNR for scenario 7, lightpath 2_1_12.5GHz
# Number of OSNR samples before: 21600
# Number of OSNR samples: 21600
#
# Scenario_7_monitor_node_1_preamp_lpth_3-1_1_12.5GHz.dat
# Plotting OSNR for scenario 7, lightpath 3-1_1_12.5GHz
# Number of OSNR samples before: 21600
# Number of OSNR samples: 21600
#
# Scenario_7_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat
# Plotting OSNR for scenario 7, lightpath 3-2_1_12.5GHz
# Number of OSNR samples before: 21600
# Number of OSNR samples: 21600
#
# Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat
# Plotting OSNR for scenario 8, lightpath 2_1_50GHz
# Number of OSNR samples before: 21600
# Number of OSNR samples: 21600
#
# Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat
# Plotting OSNR for scenario 8, lightpath 3-1_1_50GHz
# Number of OSNR samples before: 21600
# Number of OSNR samples: 21600
#
# Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat
# Plotting OSNR for scenario 8, lightpath 3-2_1_50GHz
# Number of OSNR samples before: 21600
# Number of OSNR samples: 21600

# %%
def create_window_dataset(filename, w_len=100, window_spacing=1, norm=False):
#Inputs: - filename: name of the raw data file to be read
#        - w_len: window duration, i.e., no of OSNR samples in a same window (default=100)
#        - window_spacing: distance (in number of OSNR samples) between two adjacent windows (default=1)
#Outputs: - features file (.dat) with windows dataset; 
#           each row inlcudes the following features for a window of duration w_len: Mean, RMS, P2P, STD, MAX, MIN
#           The generated file should be put in a subfolder named "Features"

    print('Creating windows dataset from file {} (window length={}; spacing={})'.format(filename,w_len,window_spacing))
    if norm:
        feature_folder='Features_norm'
    else:
        feature_folder='Features_raw'
    if not os.path.exists(feature_folder):
        os.makedirs(feature_folder)
        
    splitted_filename = filename.split('_')
    data_raw = pd.read_csv(file_path + splitted_filename[0] + '_' + splitted_filename[1] + '/' + filename, skiprows = 5)
    data_raw = data_raw.drop_duplicates(subset=[data_raw.columns.values[0]]) #F: remove duplicates with same DATE field
    
    OSNR_list = data_raw.iloc[:, -1].to_numpy(dtype='float') # keep only the last column
    
    if norm:
        OSNR_list = norm_list(OSNR_list)
        
    num_samples = len(OSNR_list) #F: counts the number of OSNR samples in the file
    
    #F: write heading line on the windows dataset file (we have 6 features in total)
    head_line=[i for i in range(6)] #F: initialization
    
    head_line[0]='mean'
    head_line[1]='RMS'
    head_line[2]='ptp'
    head_line[3]='std'
    head_line[4]='max'
    head_line[5]='min'
    
    full_filename = feature_folder + '/' + filename.rstrip('.dat') + '_sp' + str(window_spacing) + '_w' + str(w_len) + '.dat' 
    
    # Write the only the first line
    with open(full_filename, 'a') as feature_file:
            feature_file.write(','.join(head_line))
            feature_file.write('\n')
    
    # Write features for each OSNR window (one row = one window)    
    counter = 0 #F: represents the first OSNR sample of the current window being inserted in the features dataset
    last_window = False
    
    while last_window==False:
        #print('Creating window starting with sample no. {}.'.format(counter))

        # We create the window with OSNR_list indexed from "counter" to "counter + w_len"
        #F: note that last index (counter+w_len) is excluded
        OSNR_window = OSNR_list[counter : counter + w_len] #F: note that last index (counter+w_len) is excluded
        
        feature_vect = [] #F: this list stores the features for the current OSNR window
        feature_vect.append(np.mean(OSNR_window))
        feature_vect.append(np.sqrt(np.mean(OSNR_window**2))) #F: RMS
        feature_vect.append(np.ptp(OSNR_window))
        feature_vect.append(np.std(OSNR_window))
        feature_vect.append(max(OSNR_window))
        feature_vect.append(min(OSNR_window))

        # Iteration in the same line: for each "val" in "feature_vect" round "val" with 3 decimals
        str_feature_vect = [str(round(val, 3)) for val in feature_vect]
        
        with open(full_filename, 'a') as feature_file:
            feature_file.write(','.join(str_feature_vect))
            feature_file.write('\n')
            
        counter += window_spacing
        if counter + w_len > num_samples:
            print('Last window reached. Current window (with length {}) would start with ID {}, but last OSNR ID is {}\n'.format(w_len,counter,num_samples-1))
            last_window=True

# %%
##########################################################################################################
###### We use the function create_window_dataset() to generate features files for all scenarios
###### using window duration =10,20,...,100 seconds and window spacing = 1,2,...,10 seconds
##########################################################################################################

for path in Path(file_path).rglob('*_preamp_lpth_*.dat'):
    if any(s in path.name for s in without_failure):
        continue
    for windowlength in range(10,101,10):
        for spacing in range(1,11,150):
            create_window_dataset(path.name, windowlength, spacing, False)
            create_window_dataset(path.name, windowlength, spacing, True)
# Out:
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=10; spacing=1)
# Last window reached. Current window (with length 10) would start with ID 21591, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=10; spacing=1)
# Last window reached. Current window (with length 10) would start with ID 21591, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=20; spacing=1)
# Last window reached. Current window (with length 20) would start with ID 21581, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=20; spacing=1)
# Last window reached. Current window (with length 20) would start with ID 21581, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=30; spacing=1)
# Last window reached. Current window (with length 30) would start with ID 21571, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=30; spacing=1)
# Last window reached. Current window (with length 30) would start with ID 21571, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=40; spacing=1)
# Last window reached. Current window (with length 40) would start with ID 21561, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=40; spacing=1)
# Last window reached. Current window (with length 40) would start with ID 21561, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=50; spacing=1)
# Last window reached. Current window (with length 50) would start with ID 21551, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=50; spacing=1)
# Last window reached. Current window (with length 50) would start with ID 21551, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21541, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21541, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21531, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21531, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21521, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21521, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21511, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21511, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=10; spacing=1)
# Last window reached. Current window (with length 10) would start with ID 21591, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=10; spacing=1)
# Last window reached. Current window (with length 10) would start with ID 21591, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=20; spacing=1)
# Last window reached. Current window (with length 20) would start with ID 21581, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=20; spacing=1)
# Last window reached. Current window (with length 20) would start with ID 21581, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=30; spacing=1)
# Last window reached. Current window (with length 30) would start with ID 21571, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=30; spacing=1)
# Last window reached. Current window (with length 30) would start with ID 21571, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=40; spacing=1)
# Last window reached. Current window (with length 40) would start with ID 21561, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=40; spacing=1)
# Last window reached. Current window (with length 40) would start with ID 21561, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=50; spacing=1)
# Last window reached. Current window (with length 50) would start with ID 21551, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=50; spacing=1)
# Last window reached. Current window (with length 50) would start with ID 21551, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21541, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21541, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21531, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21531, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21521, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21521, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21511, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21511, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=10; spacing=1)
# Last window reached. Current window (with length 10) would start with ID 21591, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=10; spacing=1)
# Last window reached. Current window (with length 10) would start with ID 21591, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=20; spacing=1)
# Last window reached. Current window (with length 20) would start with ID 21581, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=20; spacing=1)
# Last window reached. Current window (with length 20) would start with ID 21581, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=30; spacing=1)
# Last window reached. Current window (with length 30) would start with ID 21571, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=30; spacing=1)
# Last window reached. Current window (with length 30) would start with ID 21571, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=40; spacing=1)
# Last window reached. Current window (with length 40) would start with ID 21561, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=40; spacing=1)
# Last window reached. Current window (with length 40) would start with ID 21561, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=50; spacing=1)
# Last window reached. Current window (with length 50) would start with ID 21551, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=50; spacing=1)
# Last window reached. Current window (with length 50) would start with ID 21551, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21541, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21541, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21531, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21531, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21521, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21521, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21511, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21511, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=10; spacing=1)
# Last window reached. Current window (with length 10) would start with ID 21591, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=10; spacing=1)
# Last window reached. Current window (with length 10) would start with ID 21591, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=20; spacing=1)
# Last window reached. Current window (with length 20) would start with ID 21581, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=20; spacing=1)
# Last window reached. Current window (with length 20) would start with ID 21581, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=30; spacing=1)
# Last window reached. Current window (with length 30) would start with ID 21571, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=30; spacing=1)
# Last window reached. Current window (with length 30) would start with ID 21571, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=40; spacing=1)
# Last window reached. Current window (with length 40) would start with ID 21561, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=40; spacing=1)
# Last window reached. Current window (with length 40) would start with ID 21561, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=50; spacing=1)
# Last window reached. Current window (with length 50) would start with ID 21551, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=50; spacing=1)
# Last window reached. Current window (with length 50) would start with ID 21551, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21541, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21541, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21531, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21531, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21521, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21521, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21511, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21511, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=10; spacing=1)
# Last window reached. Current window (with length 10) would start with ID 21591, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=10; spacing=1)
# Last window reached. Current window (with length 10) would start with ID 21591, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=20; spacing=1)
# Last window reached. Current window (with length 20) would start with ID 21581, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=20; spacing=1)
# Last window reached. Current window (with length 20) would start with ID 21581, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=30; spacing=1)
# Last window reached. Current window (with length 30) would start with ID 21571, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=30; spacing=1)
# Last window reached. Current window (with length 30) would start with ID 21571, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=40; spacing=1)
# Last window reached. Current window (with length 40) would start with ID 21561, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=40; spacing=1)
# Last window reached. Current window (with length 40) would start with ID 21561, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=50; spacing=1)
# Last window reached. Current window (with length 50) would start with ID 21551, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=50; spacing=1)
# Last window reached. Current window (with length 50) would start with ID 21551, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21541, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21541, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21531, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21531, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21521, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21521, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21511, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21511, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=10; spacing=1)
# Last window reached. Current window (with length 10) would start with ID 21591, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=10; spacing=1)
# Last window reached. Current window (with length 10) would start with ID 21591, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=20; spacing=1)
# Last window reached. Current window (with length 20) would start with ID 21581, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=20; spacing=1)
# Last window reached. Current window (with length 20) would start with ID 21581, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=30; spacing=1)
# Last window reached. Current window (with length 30) would start with ID 21571, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=30; spacing=1)
# Last window reached. Current window (with length 30) would start with ID 21571, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=40; spacing=1)
# Last window reached. Current window (with length 40) would start with ID 21561, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=40; spacing=1)
# Last window reached. Current window (with length 40) would start with ID 21561, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=50; spacing=1)
# Last window reached. Current window (with length 50) would start with ID 21551, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=50; spacing=1)
# Last window reached. Current window (with length 50) would start with ID 21551, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21541, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21541, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21531, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21531, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21521, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21521, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21511, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21511, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=10; spacing=1)
# Last window reached. Current window (with length 10) would start with ID 21591, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=10; spacing=1)
# Last window reached. Current window (with length 10) would start with ID 21591, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=20; spacing=1)
# Last window reached. Current window (with length 20) would start with ID 21581, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=20; spacing=1)
# Last window reached. Current window (with length 20) would start with ID 21581, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=30; spacing=1)
# Last window reached. Current window (with length 30) would start with ID 21571, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=30; spacing=1)
# Last window reached. Current window (with length 30) would start with ID 21571, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=40; spacing=1)
# Last window reached. Current window (with length 40) would start with ID 21561, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=40; spacing=1)
# Last window reached. Current window (with length 40) would start with ID 21561, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=50; spacing=1)
# Last window reached. Current window (with length 50) would start with ID 21551, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=50; spacing=1)
# Last window reached. Current window (with length 50) would start with ID 21551, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21541, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21541, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21531, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21531, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21521, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21521, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21511, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21511, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=10; spacing=1)
# Last window reached. Current window (with length 10) would start with ID 21591, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=10; spacing=1)
# Last window reached. Current window (with length 10) would start with ID 21591, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=20; spacing=1)
# Last window reached. Current window (with length 20) would start with ID 21581, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=20; spacing=1)
# Last window reached. Current window (with length 20) would start with ID 21581, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=30; spacing=1)
# Last window reached. Current window (with length 30) would start with ID 21571, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=30; spacing=1)
# Last window reached. Current window (with length 30) would start with ID 21571, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=40; spacing=1)
# Last window reached. Current window (with length 40) would start with ID 21561, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=40; spacing=1)
# Last window reached. Current window (with length 40) would start with ID 21561, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=50; spacing=1)
# Last window reached. Current window (with length 50) would start with ID 21551, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=50; spacing=1)
# Last window reached. Current window (with length 50) would start with ID 21551, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21541, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21541, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21531, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21531, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21521, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21521, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21511, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21511, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=10; spacing=1)
# Last window reached. Current window (with length 10) would start with ID 21591, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=10; spacing=1)
# Last window reached. Current window (with length 10) would start with ID 21591, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=20; spacing=1)
# Last window reached. Current window (with length 20) would start with ID 21581, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=20; spacing=1)
# Last window reached. Current window (with length 20) would start with ID 21581, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=30; spacing=1)
# Last window reached. Current window (with length 30) would start with ID 21571, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=30; spacing=1)
# Last window reached. Current window (with length 30) would start with ID 21571, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=40; spacing=1)
# Last window reached. Current window (with length 40) would start with ID 21561, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=40; spacing=1)
# Last window reached. Current window (with length 40) would start with ID 21561, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=50; spacing=1)
# Last window reached. Current window (with length 50) would start with ID 21551, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=50; spacing=1)
# Last window reached. Current window (with length 50) would start with ID 21551, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21541, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21541, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21531, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21531, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21521, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21521, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21511, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21511, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=10; spacing=1)
# Last window reached. Current window (with length 10) would start with ID 21591, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=10; spacing=1)
# Last window reached. Current window (with length 10) would start with ID 21591, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=20; spacing=1)
# Last window reached. Current window (with length 20) would start with ID 21581, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=20; spacing=1)
# Last window reached. Current window (with length 20) would start with ID 21581, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=30; spacing=1)
# Last window reached. Current window (with length 30) would start with ID 21571, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=30; spacing=1)
# Last window reached. Current window (with length 30) would start with ID 21571, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=40; spacing=1)
# Last window reached. Current window (with length 40) would start with ID 21561, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=40; spacing=1)
# Last window reached. Current window (with length 40) would start with ID 21561, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=50; spacing=1)
# Last window reached. Current window (with length 50) would start with ID 21551, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=50; spacing=1)
# Last window reached. Current window (with length 50) would start with ID 21551, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21541, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21541, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21531, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21531, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21521, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21521, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21511, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21511, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=10; spacing=1)
# Last window reached. Current window (with length 10) would start with ID 21590, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=10; spacing=1)
# Last window reached. Current window (with length 10) would start with ID 21590, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=20; spacing=1)
# Last window reached. Current window (with length 20) would start with ID 21580, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=20; spacing=1)
# Last window reached. Current window (with length 20) would start with ID 21580, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=30; spacing=1)
# Last window reached. Current window (with length 30) would start with ID 21570, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=30; spacing=1)
# Last window reached. Current window (with length 30) would start with ID 21570, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=40; spacing=1)
# Last window reached. Current window (with length 40) would start with ID 21560, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=40; spacing=1)
# Last window reached. Current window (with length 40) would start with ID 21560, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=50; spacing=1)
# Last window reached. Current window (with length 50) would start with ID 21550, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=50; spacing=1)
# Last window reached. Current window (with length 50) would start with ID 21550, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21540, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21540, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21530, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21530, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21520, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21520, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21510, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21510, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=100; spacing=1)
# ...
# Last window reached. Current window (with length 50) would start with ID 21551, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21541, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21541, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21531, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21531, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21521, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21521, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21511, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21511, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=10; spacing=1)
# Last window reached. Current window (with length 10) would start with ID 21591, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=10; spacing=1)
# Last window reached. Current window (with length 10) would start with ID 21591, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=20; spacing=1)
# Last window reached. Current window (with length 20) would start with ID 21581, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=20; spacing=1)
# Last window reached. Current window (with length 20) would start with ID 21581, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=30; spacing=1)
# Last window reached. Current window (with length 30) would start with ID 21571, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=30; spacing=1)
# Last window reached. Current window (with length 30) would start with ID 21571, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=40; spacing=1)
# Last window reached. Current window (with length 40) would start with ID 21561, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=40; spacing=1)
# Last window reached. Current window (with length 40) would start with ID 21561, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=50; spacing=1)
# Last window reached. Current window (with length 50) would start with ID 21551, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=50; spacing=1)
# Last window reached. Current window (with length 50) would start with ID 21551, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21541, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21541, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21531, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21531, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21521, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21521, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21511, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21511, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=10; spacing=1)
# Last window reached. Current window (with length 10) would start with ID 21591, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=10; spacing=1)
# Last window reached. Current window (with length 10) would start with ID 21591, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=20; spacing=1)
# Last window reached. Current window (with length 20) would start with ID 21581, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=20; spacing=1)
# Last window reached. Current window (with length 20) would start with ID 21581, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=30; spacing=1)
# Last window reached. Current window (with length 30) would start with ID 21571, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=30; spacing=1)
# Last window reached. Current window (with length 30) would start with ID 21571, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=40; spacing=1)
# Last window reached. Current window (with length 40) would start with ID 21561, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=40; spacing=1)
# Last window reached. Current window (with length 40) would start with ID 21561, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=50; spacing=1)
# Last window reached. Current window (with length 50) would start with ID 21551, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=50; spacing=1)
# Last window reached. Current window (with length 50) would start with ID 21551, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21541, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21541, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21531, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21531, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21521, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21521, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21511, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21511, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=10; spacing=1)
# Last window reached. Current window (with length 10) would start with ID 21591, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=10; spacing=1)
# Last window reached. Current window (with length 10) would start with ID 21591, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=20; spacing=1)
# Last window reached. Current window (with length 20) would start with ID 21581, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=20; spacing=1)
# Last window reached. Current window (with length 20) would start with ID 21581, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=30; spacing=1)
# Last window reached. Current window (with length 30) would start with ID 21571, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=30; spacing=1)
# Last window reached. Current window (with length 30) would start with ID 21571, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=40; spacing=1)
# Last window reached. Current window (with length 40) would start with ID 21561, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=40; spacing=1)
# Last window reached. Current window (with length 40) would start with ID 21561, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=50; spacing=1)
# Last window reached. Current window (with length 50) would start with ID 21551, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=50; spacing=1)
# Last window reached. Current window (with length 50) would start with ID 21551, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21541, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=60; spacing=1)
# Last window reached. Current window (with length 60) would start with ID 21541, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21531, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=70; spacing=1)
# Last window reached. Current window (with length 70) would start with ID 21531, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21521, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=80; spacing=1)
# Last window reached. Current window (with length 80) would start with ID 21521, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21511, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=90; spacing=1)
# Last window reached. Current window (with length 90) would start with ID 21511, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599

# %%
for path in Path(file_path).rglob('*_preamp_lpth_*.dat'):
    if any(s in path.name for s in without_failure):
        continue
    for windowlength in range(200,3601,100):
        create_window_dataset(path.name, windowlength, 1, False)
# Out:
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=200; spacing=1)
# Last window reached. Current window (with length 200) would start with ID 21401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=300; spacing=1)
# Last window reached. Current window (with length 300) would start with ID 21301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=400; spacing=1)
# Last window reached. Current window (with length 400) would start with ID 21201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=500; spacing=1)
# Last window reached. Current window (with length 500) would start with ID 21101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=600; spacing=1)
# Last window reached. Current window (with length 600) would start with ID 21001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=700; spacing=1)
# Last window reached. Current window (with length 700) would start with ID 20901, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=800; spacing=1)
# Last window reached. Current window (with length 800) would start with ID 20801, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=900; spacing=1)
# Last window reached. Current window (with length 900) would start with ID 20701, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=1000; spacing=1)
# Last window reached. Current window (with length 1000) would start with ID 20601, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=1100; spacing=1)
# Last window reached. Current window (with length 1100) would start with ID 20501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=1200; spacing=1)
# Last window reached. Current window (with length 1200) would start with ID 20401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=1300; spacing=1)
# Last window reached. Current window (with length 1300) would start with ID 20301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=1400; spacing=1)
# Last window reached. Current window (with length 1400) would start with ID 20201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=1500; spacing=1)
# Last window reached. Current window (with length 1500) would start with ID 20101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=1600; spacing=1)
# Last window reached. Current window (with length 1600) would start with ID 20001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=1700; spacing=1)
# Last window reached. Current window (with length 1700) would start with ID 19901, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=1800; spacing=1)
# Last window reached. Current window (with length 1800) would start with ID 19801, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=1900; spacing=1)
# Last window reached. Current window (with length 1900) would start with ID 19701, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=2000; spacing=1)
# Last window reached. Current window (with length 2000) would start with ID 19601, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=2100; spacing=1)
# Last window reached. Current window (with length 2100) would start with ID 19501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=2200; spacing=1)
# Last window reached. Current window (with length 2200) would start with ID 19401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=2300; spacing=1)
# Last window reached. Current window (with length 2300) would start with ID 19301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=2400; spacing=1)
# Last window reached. Current window (with length 2400) would start with ID 19201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=2500; spacing=1)
# Last window reached. Current window (with length 2500) would start with ID 19101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=2600; spacing=1)
# Last window reached. Current window (with length 2600) would start with ID 19001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=2700; spacing=1)
# Last window reached. Current window (with length 2700) would start with ID 18901, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=2800; spacing=1)
# Last window reached. Current window (with length 2800) would start with ID 18801, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=2900; spacing=1)
# Last window reached. Current window (with length 2900) would start with ID 18701, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=3000; spacing=1)
# Last window reached. Current window (with length 3000) would start with ID 18601, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=3100; spacing=1)
# Last window reached. Current window (with length 3100) would start with ID 18501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=3200; spacing=1)
# Last window reached. Current window (with length 3200) would start with ID 18401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=3300; spacing=1)
# Last window reached. Current window (with length 3300) would start with ID 18301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=3400; spacing=1)
# Last window reached. Current window (with length 3400) would start with ID 18201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=3500; spacing=1)
# Last window reached. Current window (with length 3500) would start with ID 18101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=3600; spacing=1)
# Last window reached. Current window (with length 3600) would start with ID 18001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=200; spacing=1)
# Last window reached. Current window (with length 200) would start with ID 21401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=300; spacing=1)
# Last window reached. Current window (with length 300) would start with ID 21301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=400; spacing=1)
# Last window reached. Current window (with length 400) would start with ID 21201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=500; spacing=1)
# Last window reached. Current window (with length 500) would start with ID 21101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=600; spacing=1)
# Last window reached. Current window (with length 600) would start with ID 21001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=700; spacing=1)
# Last window reached. Current window (with length 700) would start with ID 20901, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=800; spacing=1)
# Last window reached. Current window (with length 800) would start with ID 20801, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=900; spacing=1)
# Last window reached. Current window (with length 900) would start with ID 20701, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=1000; spacing=1)
# Last window reached. Current window (with length 1000) would start with ID 20601, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=1100; spacing=1)
# Last window reached. Current window (with length 1100) would start with ID 20501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=1200; spacing=1)
# Last window reached. Current window (with length 1200) would start with ID 20401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=1300; spacing=1)
# Last window reached. Current window (with length 1300) would start with ID 20301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=1400; spacing=1)
# Last window reached. Current window (with length 1400) would start with ID 20201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=1500; spacing=1)
# Last window reached. Current window (with length 1500) would start with ID 20101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=1600; spacing=1)
# Last window reached. Current window (with length 1600) would start with ID 20001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=1700; spacing=1)
# Last window reached. Current window (with length 1700) would start with ID 19901, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=1800; spacing=1)
# Last window reached. Current window (with length 1800) would start with ID 19801, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=1900; spacing=1)
# Last window reached. Current window (with length 1900) would start with ID 19701, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=2000; spacing=1)
# Last window reached. Current window (with length 2000) would start with ID 19601, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=2100; spacing=1)
# Last window reached. Current window (with length 2100) would start with ID 19501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=2200; spacing=1)
# Last window reached. Current window (with length 2200) would start with ID 19401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=2300; spacing=1)
# Last window reached. Current window (with length 2300) would start with ID 19301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=2400; spacing=1)
# Last window reached. Current window (with length 2400) would start with ID 19201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=2500; spacing=1)
# Last window reached. Current window (with length 2500) would start with ID 19101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=2600; spacing=1)
# Last window reached. Current window (with length 2600) would start with ID 19001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=2700; spacing=1)
# Last window reached. Current window (with length 2700) would start with ID 18901, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=2800; spacing=1)
# Last window reached. Current window (with length 2800) would start with ID 18801, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=2900; spacing=1)
# Last window reached. Current window (with length 2900) would start with ID 18701, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=3000; spacing=1)
# Last window reached. Current window (with length 3000) would start with ID 18601, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=3100; spacing=1)
# Last window reached. Current window (with length 3100) would start with ID 18501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=3200; spacing=1)
# Last window reached. Current window (with length 3200) would start with ID 18401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=3300; spacing=1)
# Last window reached. Current window (with length 3300) would start with ID 18301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=3400; spacing=1)
# Last window reached. Current window (with length 3400) would start with ID 18201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=3500; spacing=1)
# Last window reached. Current window (with length 3500) would start with ID 18101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=3600; spacing=1)
# Last window reached. Current window (with length 3600) would start with ID 18001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=200; spacing=1)
# Last window reached. Current window (with length 200) would start with ID 21401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=300; spacing=1)
# Last window reached. Current window (with length 300) would start with ID 21301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=400; spacing=1)
# Last window reached. Current window (with length 400) would start with ID 21201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=500; spacing=1)
# Last window reached. Current window (with length 500) would start with ID 21101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=600; spacing=1)
# Last window reached. Current window (with length 600) would start with ID 21001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=700; spacing=1)
# Last window reached. Current window (with length 700) would start with ID 20901, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=800; spacing=1)
# Last window reached. Current window (with length 800) would start with ID 20801, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=900; spacing=1)
# Last window reached. Current window (with length 900) would start with ID 20701, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=1000; spacing=1)
# Last window reached. Current window (with length 1000) would start with ID 20601, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=1100; spacing=1)
# Last window reached. Current window (with length 1100) would start with ID 20501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=1200; spacing=1)
# Last window reached. Current window (with length 1200) would start with ID 20401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=1300; spacing=1)
# Last window reached. Current window (with length 1300) would start with ID 20301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=1400; spacing=1)
# Last window reached. Current window (with length 1400) would start with ID 20201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=1500; spacing=1)
# Last window reached. Current window (with length 1500) would start with ID 20101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=1600; spacing=1)
# Last window reached. Current window (with length 1600) would start with ID 20001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=1700; spacing=1)
# Last window reached. Current window (with length 1700) would start with ID 19901, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=1800; spacing=1)
# Last window reached. Current window (with length 1800) would start with ID 19801, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=1900; spacing=1)
# Last window reached. Current window (with length 1900) would start with ID 19701, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=2000; spacing=1)
# Last window reached. Current window (with length 2000) would start with ID 19601, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=2100; spacing=1)
# Last window reached. Current window (with length 2100) would start with ID 19501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=2200; spacing=1)
# Last window reached. Current window (with length 2200) would start with ID 19401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=2300; spacing=1)
# Last window reached. Current window (with length 2300) would start with ID 19301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=2400; spacing=1)
# Last window reached. Current window (with length 2400) would start with ID 19201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=2500; spacing=1)
# Last window reached. Current window (with length 2500) would start with ID 19101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=2600; spacing=1)
# Last window reached. Current window (with length 2600) would start with ID 19001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=2700; spacing=1)
# Last window reached. Current window (with length 2700) would start with ID 18901, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=2800; spacing=1)
# Last window reached. Current window (with length 2800) would start with ID 18801, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=2900; spacing=1)
# Last window reached. Current window (with length 2900) would start with ID 18701, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=3000; spacing=1)
# Last window reached. Current window (with length 3000) would start with ID 18601, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=3100; spacing=1)
# Last window reached. Current window (with length 3100) would start with ID 18501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=3200; spacing=1)
# Last window reached. Current window (with length 3200) would start with ID 18401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=3300; spacing=1)
# Last window reached. Current window (with length 3300) would start with ID 18301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=3400; spacing=1)
# Last window reached. Current window (with length 3400) would start with ID 18201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=3500; spacing=1)
# Last window reached. Current window (with length 3500) would start with ID 18101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=3600; spacing=1)
# Last window reached. Current window (with length 3600) would start with ID 18001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=200; spacing=1)
# Last window reached. Current window (with length 200) would start with ID 21401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=300; spacing=1)
# Last window reached. Current window (with length 300) would start with ID 21301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=400; spacing=1)
# Last window reached. Current window (with length 400) would start with ID 21201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=500; spacing=1)
# Last window reached. Current window (with length 500) would start with ID 21101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=600; spacing=1)
# Last window reached. Current window (with length 600) would start with ID 21001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=700; spacing=1)
# Last window reached. Current window (with length 700) would start with ID 20901, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=800; spacing=1)
# Last window reached. Current window (with length 800) would start with ID 20801, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=900; spacing=1)
# Last window reached. Current window (with length 900) would start with ID 20701, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=1000; spacing=1)
# Last window reached. Current window (with length 1000) would start with ID 20601, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=1100; spacing=1)
# Last window reached. Current window (with length 1100) would start with ID 20501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=1200; spacing=1)
# Last window reached. Current window (with length 1200) would start with ID 20401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=1300; spacing=1)
# Last window reached. Current window (with length 1300) would start with ID 20301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=1400; spacing=1)
# Last window reached. Current window (with length 1400) would start with ID 20201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=1500; spacing=1)
# Last window reached. Current window (with length 1500) would start with ID 20101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=1600; spacing=1)
# Last window reached. Current window (with length 1600) would start with ID 20001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=1700; spacing=1)
# Last window reached. Current window (with length 1700) would start with ID 19901, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=1800; spacing=1)
# Last window reached. Current window (with length 1800) would start with ID 19801, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=1900; spacing=1)
# Last window reached. Current window (with length 1900) would start with ID 19701, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=2000; spacing=1)
# Last window reached. Current window (with length 2000) would start with ID 19601, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=2100; spacing=1)
# Last window reached. Current window (with length 2100) would start with ID 19501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=2200; spacing=1)
# Last window reached. Current window (with length 2200) would start with ID 19401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=2300; spacing=1)
# Last window reached. Current window (with length 2300) would start with ID 19301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=2400; spacing=1)
# Last window reached. Current window (with length 2400) would start with ID 19201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=2500; spacing=1)
# Last window reached. Current window (with length 2500) would start with ID 19101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=2600; spacing=1)
# Last window reached. Current window (with length 2600) would start with ID 19001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=2700; spacing=1)
# Last window reached. Current window (with length 2700) would start with ID 18901, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=2800; spacing=1)
# Last window reached. Current window (with length 2800) would start with ID 18801, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=2900; spacing=1)
# Last window reached. Current window (with length 2900) would start with ID 18701, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=3000; spacing=1)
# Last window reached. Current window (with length 3000) would start with ID 18601, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=3100; spacing=1)
# Last window reached. Current window (with length 3100) would start with ID 18501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=3200; spacing=1)
# Last window reached. Current window (with length 3200) would start with ID 18401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=3300; spacing=1)
# Last window reached. Current window (with length 3300) would start with ID 18301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=3400; spacing=1)
# Last window reached. Current window (with length 3400) would start with ID 18201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=3500; spacing=1)
# Last window reached. Current window (with length 3500) would start with ID 18101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=3600; spacing=1)
# Last window reached. Current window (with length 3600) would start with ID 18001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=200; spacing=1)
# Last window reached. Current window (with length 200) would start with ID 21401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=300; spacing=1)
# Last window reached. Current window (with length 300) would start with ID 21301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=400; spacing=1)
# Last window reached. Current window (with length 400) would start with ID 21201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=500; spacing=1)
# Last window reached. Current window (with length 500) would start with ID 21101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=600; spacing=1)
# Last window reached. Current window (with length 600) would start with ID 21001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=700; spacing=1)
# Last window reached. Current window (with length 700) would start with ID 20901, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=800; spacing=1)
# Last window reached. Current window (with length 800) would start with ID 20801, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=900; spacing=1)
# Last window reached. Current window (with length 900) would start with ID 20701, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=1000; spacing=1)
# Last window reached. Current window (with length 1000) would start with ID 20601, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=1100; spacing=1)
# Last window reached. Current window (with length 1100) would start with ID 20501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=1200; spacing=1)
# Last window reached. Current window (with length 1200) would start with ID 20401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=1300; spacing=1)
# Last window reached. Current window (with length 1300) would start with ID 20301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=1400; spacing=1)
# Last window reached. Current window (with length 1400) would start with ID 20201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=1500; spacing=1)
# Last window reached. Current window (with length 1500) would start with ID 20101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=1600; spacing=1)
# Last window reached. Current window (with length 1600) would start with ID 20001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=1700; spacing=1)
# Last window reached. Current window (with length 1700) would start with ID 19901, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=1800; spacing=1)
# Last window reached. Current window (with length 1800) would start with ID 19801, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=1900; spacing=1)
# Last window reached. Current window (with length 1900) would start with ID 19701, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=2000; spacing=1)
# Last window reached. Current window (with length 2000) would start with ID 19601, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=2100; spacing=1)
# Last window reached. Current window (with length 2100) would start with ID 19501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=2200; spacing=1)
# Last window reached. Current window (with length 2200) would start with ID 19401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=2300; spacing=1)
# Last window reached. Current window (with length 2300) would start with ID 19301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=2400; spacing=1)
# Last window reached. Current window (with length 2400) would start with ID 19201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=2500; spacing=1)
# Last window reached. Current window (with length 2500) would start with ID 19101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=2600; spacing=1)
# Last window reached. Current window (with length 2600) would start with ID 19001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=2700; spacing=1)
# Last window reached. Current window (with length 2700) would start with ID 18901, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=2800; spacing=1)
# Last window reached. Current window (with length 2800) would start with ID 18801, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=2900; spacing=1)
# Last window reached. Current window (with length 2900) would start with ID 18701, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=3000; spacing=1)
# Last window reached. Current window (with length 3000) would start with ID 18601, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=3100; spacing=1)
# Last window reached. Current window (with length 3100) would start with ID 18501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=3200; spacing=1)
# Last window reached. Current window (with length 3200) would start with ID 18401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=3300; spacing=1)
# Last window reached. Current window (with length 3300) would start with ID 18301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=3400; spacing=1)
# Last window reached. Current window (with length 3400) would start with ID 18201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=3500; spacing=1)
# Last window reached. Current window (with length 3500) would start with ID 18101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=3600; spacing=1)
# Last window reached. Current window (with length 3600) would start with ID 18001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=200; spacing=1)
# Last window reached. Current window (with length 200) would start with ID 21401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=300; spacing=1)
# Last window reached. Current window (with length 300) would start with ID 21301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=400; spacing=1)
# Last window reached. Current window (with length 400) would start with ID 21201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=500; spacing=1)
# Last window reached. Current window (with length 500) would start with ID 21101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=600; spacing=1)
# Last window reached. Current window (with length 600) would start with ID 21001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=700; spacing=1)
# Last window reached. Current window (with length 700) would start with ID 20901, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=800; spacing=1)
# Last window reached. Current window (with length 800) would start with ID 20801, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=900; spacing=1)
# Last window reached. Current window (with length 900) would start with ID 20701, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=1000; spacing=1)
# Last window reached. Current window (with length 1000) would start with ID 20601, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=1100; spacing=1)
# Last window reached. Current window (with length 1100) would start with ID 20501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=1200; spacing=1)
# Last window reached. Current window (with length 1200) would start with ID 20401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=1300; spacing=1)
# Last window reached. Current window (with length 1300) would start with ID 20301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=1400; spacing=1)
# Last window reached. Current window (with length 1400) would start with ID 20201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=1500; spacing=1)
# Last window reached. Current window (with length 1500) would start with ID 20101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=1600; spacing=1)
# Last window reached. Current window (with length 1600) would start with ID 20001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=1700; spacing=1)
# Last window reached. Current window (with length 1700) would start with ID 19901, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=1800; spacing=1)
# Last window reached. Current window (with length 1800) would start with ID 19801, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=1900; spacing=1)
# Last window reached. Current window (with length 1900) would start with ID 19701, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=2000; spacing=1)
# Last window reached. Current window (with length 2000) would start with ID 19601, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=2100; spacing=1)
# Last window reached. Current window (with length 2100) would start with ID 19501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=2200; spacing=1)
# Last window reached. Current window (with length 2200) would start with ID 19401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=2300; spacing=1)
# Last window reached. Current window (with length 2300) would start with ID 19301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=2400; spacing=1)
# Last window reached. Current window (with length 2400) would start with ID 19201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=2500; spacing=1)
# Last window reached. Current window (with length 2500) would start with ID 19101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=2600; spacing=1)
# Last window reached. Current window (with length 2600) would start with ID 19001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=2700; spacing=1)
# Last window reached. Current window (with length 2700) would start with ID 18901, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=2800; spacing=1)
# Last window reached. Current window (with length 2800) would start with ID 18801, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=2900; spacing=1)
# Last window reached. Current window (with length 2900) would start with ID 18701, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=3000; spacing=1)
# Last window reached. Current window (with length 3000) would start with ID 18601, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=3100; spacing=1)
# Last window reached. Current window (with length 3100) would start with ID 18501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=3200; spacing=1)
# Last window reached. Current window (with length 3200) would start with ID 18401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=3300; spacing=1)
# Last window reached. Current window (with length 3300) would start with ID 18301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=3400; spacing=1)
# Last window reached. Current window (with length 3400) would start with ID 18201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=3500; spacing=1)
# Last window reached. Current window (with length 3500) would start with ID 18101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=3600; spacing=1)
# ...
# Last window reached. Current window (with length 300) would start with ID 21301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=400; spacing=1)
# Last window reached. Current window (with length 400) would start with ID 21201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=500; spacing=1)
# Last window reached. Current window (with length 500) would start with ID 21101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=600; spacing=1)
# Last window reached. Current window (with length 600) would start with ID 21001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=700; spacing=1)
# Last window reached. Current window (with length 700) would start with ID 20901, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=800; spacing=1)
# Last window reached. Current window (with length 800) would start with ID 20801, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=900; spacing=1)
# Last window reached. Current window (with length 900) would start with ID 20701, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=1000; spacing=1)
# Last window reached. Current window (with length 1000) would start with ID 20601, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=1100; spacing=1)
# Last window reached. Current window (with length 1100) would start with ID 20501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=1200; spacing=1)
# Last window reached. Current window (with length 1200) would start with ID 20401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=1300; spacing=1)
# Last window reached. Current window (with length 1300) would start with ID 20301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=1400; spacing=1)
# Last window reached. Current window (with length 1400) would start with ID 20201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=1500; spacing=1)
# Last window reached. Current window (with length 1500) would start with ID 20101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=1600; spacing=1)
# Last window reached. Current window (with length 1600) would start with ID 20001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=1700; spacing=1)
# Last window reached. Current window (with length 1700) would start with ID 19901, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=1800; spacing=1)
# Last window reached. Current window (with length 1800) would start with ID 19801, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=1900; spacing=1)
# Last window reached. Current window (with length 1900) would start with ID 19701, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=2000; spacing=1)
# Last window reached. Current window (with length 2000) would start with ID 19601, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=2100; spacing=1)
# Last window reached. Current window (with length 2100) would start with ID 19501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=2200; spacing=1)
# Last window reached. Current window (with length 2200) would start with ID 19401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=2300; spacing=1)
# Last window reached. Current window (with length 2300) would start with ID 19301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=2400; spacing=1)
# Last window reached. Current window (with length 2400) would start with ID 19201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=2500; spacing=1)
# Last window reached. Current window (with length 2500) would start with ID 19101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=2600; spacing=1)
# Last window reached. Current window (with length 2600) would start with ID 19001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=2700; spacing=1)
# Last window reached. Current window (with length 2700) would start with ID 18901, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=2800; spacing=1)
# Last window reached. Current window (with length 2800) would start with ID 18801, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=2900; spacing=1)
# Last window reached. Current window (with length 2900) would start with ID 18701, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=3000; spacing=1)
# Last window reached. Current window (with length 3000) would start with ID 18601, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=3100; spacing=1)
# Last window reached. Current window (with length 3100) would start with ID 18501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=3200; spacing=1)
# Last window reached. Current window (with length 3200) would start with ID 18401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=3300; spacing=1)
# Last window reached. Current window (with length 3300) would start with ID 18301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=3400; spacing=1)
# Last window reached. Current window (with length 3400) would start with ID 18201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=3500; spacing=1)
# Last window reached. Current window (with length 3500) would start with ID 18101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=3600; spacing=1)
# Last window reached. Current window (with length 3600) would start with ID 18001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=100; spacing=1)
# Last window reached. Current window (with length 100) would start with ID 21501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=200; spacing=1)
# Last window reached. Current window (with length 200) would start with ID 21401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=300; spacing=1)
# Last window reached. Current window (with length 300) would start with ID 21301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=400; spacing=1)
# Last window reached. Current window (with length 400) would start with ID 21201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=500; spacing=1)
# Last window reached. Current window (with length 500) would start with ID 21101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=600; spacing=1)
# Last window reached. Current window (with length 600) would start with ID 21001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=700; spacing=1)
# Last window reached. Current window (with length 700) would start with ID 20901, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=800; spacing=1)
# Last window reached. Current window (with length 800) would start with ID 20801, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=900; spacing=1)
# Last window reached. Current window (with length 900) would start with ID 20701, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=1000; spacing=1)
# Last window reached. Current window (with length 1000) would start with ID 20601, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=1100; spacing=1)
# Last window reached. Current window (with length 1100) would start with ID 20501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=1200; spacing=1)
# Last window reached. Current window (with length 1200) would start with ID 20401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=1300; spacing=1)
# Last window reached. Current window (with length 1300) would start with ID 20301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=1400; spacing=1)
# Last window reached. Current window (with length 1400) would start with ID 20201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=1500; spacing=1)
# Last window reached. Current window (with length 1500) would start with ID 20101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=1600; spacing=1)
# Last window reached. Current window (with length 1600) would start with ID 20001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=1700; spacing=1)
# Last window reached. Current window (with length 1700) would start with ID 19901, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=1800; spacing=1)
# Last window reached. Current window (with length 1800) would start with ID 19801, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=1900; spacing=1)
# Last window reached. Current window (with length 1900) would start with ID 19701, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=2000; spacing=1)
# Last window reached. Current window (with length 2000) would start with ID 19601, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=2100; spacing=1)
# Last window reached. Current window (with length 2100) would start with ID 19501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=2200; spacing=1)
# Last window reached. Current window (with length 2200) would start with ID 19401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=2300; spacing=1)
# Last window reached. Current window (with length 2300) would start with ID 19301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=2400; spacing=1)
# Last window reached. Current window (with length 2400) would start with ID 19201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=2500; spacing=1)
# Last window reached. Current window (with length 2500) would start with ID 19101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=2600; spacing=1)
# Last window reached. Current window (with length 2600) would start with ID 19001, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=2700; spacing=1)
# Last window reached. Current window (with length 2700) would start with ID 18901, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=2800; spacing=1)
# Last window reached. Current window (with length 2800) would start with ID 18801, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=2900; spacing=1)
# Last window reached. Current window (with length 2900) would start with ID 18701, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=3000; spacing=1)
# Last window reached. Current window (with length 3000) would start with ID 18601, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=3100; spacing=1)
# Last window reached. Current window (with length 3100) would start with ID 18501, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=3200; spacing=1)
# Last window reached. Current window (with length 3200) would start with ID 18401, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=3300; spacing=1)
# Last window reached. Current window (with length 3300) would start with ID 18301, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=3400; spacing=1)
# Last window reached. Current window (with length 3400) would start with ID 18201, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=3500; spacing=1)
# Last window reached. Current window (with length 3500) would start with ID 18101, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=3600; spacing=1)
# Last window reached. Current window (with length 3600) would start with ID 18001, but last OSNR ID is 21599

# %%
for path in Path(file_path).rglob('*_preamp_lpth_*.dat'):
    if any(s in path.name for s in without_failure):
        continue
    for spacing in range(10,161,10):
        create_window_dataset(path.name, 80, spacing, False)
# Out:
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=10)
# Last window reached. Current window (with length 80) would start with ID 21530, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=20)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=30)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=40)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=50)
# Last window reached. Current window (with length 80) would start with ID 21550, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=60)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=70)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=80)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=90)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=100)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=110)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=120)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=130)
# Last window reached. Current window (with length 80) would start with ID 21580, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=140)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=150)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=160)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=10)
# Last window reached. Current window (with length 80) would start with ID 21530, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=20)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=30)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=40)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=50)
# Last window reached. Current window (with length 80) would start with ID 21550, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=60)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=70)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=80)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=90)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=100)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=110)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=120)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=130)
# Last window reached. Current window (with length 80) would start with ID 21580, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=140)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=150)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=160)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=10)
# Last window reached. Current window (with length 80) would start with ID 21530, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=20)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=30)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=40)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=50)
# Last window reached. Current window (with length 80) would start with ID 21550, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=60)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=70)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=80)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=90)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=100)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=110)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=120)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=130)
# Last window reached. Current window (with length 80) would start with ID 21580, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=140)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=150)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_1_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=160)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=10)
# Last window reached. Current window (with length 80) would start with ID 21530, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=20)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=30)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=40)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=50)
# Last window reached. Current window (with length 80) would start with ID 21550, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=60)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=70)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=80)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=90)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=100)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=110)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=120)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=130)
# Last window reached. Current window (with length 80) would start with ID 21580, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=140)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=150)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=160)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=10)
# Last window reached. Current window (with length 80) would start with ID 21530, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=20)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=30)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=40)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=50)
# Last window reached. Current window (with length 80) would start with ID 21550, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=60)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=70)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=80)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=90)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=100)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=110)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=120)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=130)
# Last window reached. Current window (with length 80) would start with ID 21580, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=140)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=150)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_2_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=160)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=10)
# Last window reached. Current window (with length 80) would start with ID 21530, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=20)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=30)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=40)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=50)
# Last window reached. Current window (with length 80) would start with ID 21550, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=60)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=70)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=80)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=90)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=100)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=110)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=120)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=130)
# Last window reached. Current window (with length 80) would start with ID 21580, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=140)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=150)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_3_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=160)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=10)
# Last window reached. Current window (with length 80) would start with ID 21530, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=20)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=30)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=40)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=50)
# Last window reached. Current window (with length 80) would start with ID 21550, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=60)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=70)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=80)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=90)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=100)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=110)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=120)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=130)
# Last window reached. Current window (with length 80) would start with ID 21580, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=140)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=150)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=160)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=10)
# Last window reached. Current window (with length 80) would start with ID 21530, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=20)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=30)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=40)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=50)
# Last window reached. Current window (with length 80) would start with ID 21550, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=60)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=70)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=80)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=90)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=100)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=110)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=120)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=130)
# Last window reached. Current window (with length 80) would start with ID 21580, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=140)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=150)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=160)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=10)
# Last window reached. Current window (with length 80) would start with ID 21530, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=20)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=30)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=40)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=50)
# Last window reached. Current window (with length 80) would start with ID 21550, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=60)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=70)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=80)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=90)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=100)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=110)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=120)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=130)
# Last window reached. Current window (with length 80) would start with ID 21580, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=140)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=150)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_4_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=160)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=10)
# Last window reached. Current window (with length 80) would start with ID 21530, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=20)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=30)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=40)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=50)
# Last window reached. Current window (with length 80) would start with ID 21550, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=60)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=70)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=80)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=90)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=100)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=110)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=120)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=130)
# Last window reached. Current window (with length 80) would start with ID 21580, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=140)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=150)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_2_1.dat (window length=80; spacing=160)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=10)
# Last window reached. Current window (with length 80) would start with ID 21520, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=20)
# Last window reached. Current window (with length 80) would start with ID 21520, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=30)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=40)
# Last window reached. Current window (with length 80) would start with ID 21520, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=50)
# Last window reached. Current window (with length 80) would start with ID 21550, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=60)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=70)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=80)
# Last window reached. Current window (with length 80) would start with ID 21520, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=90)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=100)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=110)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=120)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=130)
# Last window reached. Current window (with length 80) would start with ID 21580, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=140)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=150)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-1_1.dat (window length=80; spacing=160)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=10)
# Last window reached. Current window (with length 80) would start with ID 21520, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=20)
# Last window reached. Current window (with length 80) would start with ID 21520, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=30)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=40)
# Last window reached. Current window (with length 80) would start with ID 21520, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=50)
# Last window reached. Current window (with length 80) would start with ID 21550, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=60)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=70)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=80)
# Last window reached. Current window (with length 80) would start with ID 21520, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=90)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=100)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=110)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=120)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=130)
# Last window reached. Current window (with length 80) would start with ID 21580, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=140)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=150)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_5_monitor_node_1_preamp_lpth_3-2_1.dat (window length=80; spacing=160)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21598
#
# Creating windows dataset from file Scenario_6_monitor_node_1_preamp_lpth_3-2_1_100GHz.dat (window length=80; spacing=10)
# Last window reached. Current window (with length 80) would start with ID 530, but last OSNR ID is 599
#
# Creating windows dataset from file Scenario_6_monitor_node_1_preamp_lpth_3-2_1_100GHz.dat (window length=80; spacing=20)
# Last window reached. Current window (with length 80) would start with ID 540, but last OSNR ID is 599
#
# Creating windows dataset from file Scenario_6_monitor_node_1_preamp_lpth_3-2_1_100GHz.dat (window length=80; spacing=30)
# Last window reached. Current window (with length 80) would start with ID 540, but last OSNR ID is 599
#
# Creating windows dataset from file Scenario_6_monitor_node_1_preamp_lpth_3-2_1_100GHz.dat (window length=80; spacing=40)
# Last window reached. Current window (with length 80) would start with ID 560, but last OSNR ID is 599
#
# Creating windows dataset from file Scenario_6_monitor_node_1_preamp_lpth_3-2_1_100GHz.dat (window length=80; spacing=50)
# Last window reached. Current window (with length 80) would start with ID 550, but last OSNR ID is 599
#
# Creating windows dataset from file Scenario_6_monitor_node_1_preamp_lpth_3-2_1_100GHz.dat (window length=80; spacing=60)
# Last window reached. Current window (with length 80) would start with ID 540, but last OSNR ID is 599
#
# Creating windows dataset from file Scenario_6_monitor_node_1_preamp_lpth_3-2_1_100GHz.dat (window length=80; spacing=70)
# Last window reached. Current window (with length 80) would start with ID 560, but last OSNR ID is 599
#
# Creating windows dataset from file Scenario_6_monitor_node_1_preamp_lpth_3-2_1_100GHz.dat (window length=80; spacing=80)
# Last window reached. Current window (with length 80) would start with ID 560, but last OSNR ID is 599
#
# Creating windows dataset from file Scenario_6_monitor_node_1_preamp_lpth_3-2_1_100GHz.dat (window length=80; spacing=90)
# Last window reached. Current window (with length 80) would start with ID 540, but last OSNR ID is 599
#
# Creating windows dataset from file Scenario_6_monitor_node_1_preamp_lpth_3-2_1_100GHz.dat (window length=80; spacing=100)
# Last window reached. Current window (with length 80) would start with ID 600, but last OSNR ID is 599
#
# Creating windows dataset from file Scenario_6_monitor_node_1_preamp_lpth_3-2_1_100GHz.dat (window length=80; spacing=110)
# Last window reached. Current window (with length 80) would start with ID 550, but last OSNR ID is 599
#
# Creating windows dataset from file Scenario_6_monitor_node_1_preamp_lpth_3-2_1_100GHz.dat (window length=80; spacing=120)
# Last window reached. Current window (with length 80) would start with ID 600, but last OSNR ID is 599
#
# Creating windows dataset from file Scenario_6_monitor_node_1_preamp_lpth_3-2_1_100GHz.dat (window length=80; spacing=130)
# Last window reached. Current window (with length 80) would start with ID 650, but last OSNR ID is 599
#
# Creating windows dataset from file Scenario_6_monitor_node_1_preamp_lpth_3-2_1_100GHz.dat (window length=80; spacing=140)
# Last window reached. Current window (with length 80) would start with ID 560, but last OSNR ID is 599
#
# Creating windows dataset from file Scenario_6_monitor_node_1_preamp_lpth_3-2_1_100GHz.dat (window length=80; spacing=150)
# Last window reached. Current window (with length 80) would start with ID 600, but last OSNR ID is 599
#
# Creating windows dataset from file Scenario_6_monitor_node_1_preamp_lpth_3-2_1_100GHz.dat (window length=80; spacing=160)
# Last window reached. Current window (with length 80) would start with ID 640, but last OSNR ID is 599
#
# Creating windows dataset from file Scenario_6_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=80; spacing=10)
# Last window reached. Current window (with length 80) would start with ID 230, but last OSNR ID is 299
#
# Creating windows dataset from file Scenario_6_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=80; spacing=20)
# Last window reached. Current window (with length 80) would start with ID 240, but last OSNR ID is 299
#
# Creating windows dataset from file Scenario_6_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=80; spacing=30)
# Last window reached. Current window (with length 80) would start with ID 240, but last OSNR ID is 299
#
# Creating windows dataset from file Scenario_6_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=80; spacing=40)
# Last window reached. Current window (with length 80) would start with ID 240, but last OSNR ID is 299
#
# Creating windows dataset from file Scenario_6_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=80; spacing=50)
# Last window reached. Current window (with length 80) would start with ID 250, but last OSNR ID is 299
#
# Creating windows dataset from file Scenario_6_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=80; spacing=60)
# Last window reached. Current window (with length 80) would start with ID 240, but last OSNR ID is 299
#
# Creating windows dataset from file Scenario_6_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=80; spacing=70)
# Last window reached. Current window (with length 80) would start with ID 280, but last OSNR ID is 299
#
# Creating windows dataset from file Scenario_6_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=80; spacing=80)
# Last window reached. Current window (with length 80) would start with ID 240, but last OSNR ID is 299
#
# Creating windows dataset from file Scenario_6_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=80; spacing=90)
# Last window reached. Current window (with length 80) would start with ID 270, but last OSNR ID is 299
#
# ...
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-1_1_12.5GHz.dat (window length=80; spacing=110)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-1_1_12.5GHz.dat (window length=80; spacing=120)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-1_1_12.5GHz.dat (window length=80; spacing=130)
# Last window reached. Current window (with length 80) would start with ID 21580, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-1_1_12.5GHz.dat (window length=80; spacing=140)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-1_1_12.5GHz.dat (window length=80; spacing=150)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-1_1_12.5GHz.dat (window length=80; spacing=160)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=80; spacing=10)
# Last window reached. Current window (with length 80) would start with ID 21530, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=80; spacing=20)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=80; spacing=30)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=80; spacing=40)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=80; spacing=50)
# Last window reached. Current window (with length 80) would start with ID 21550, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=80; spacing=60)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=80; spacing=70)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=80; spacing=80)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=80; spacing=90)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=80; spacing=100)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=80; spacing=110)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=80; spacing=120)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=80; spacing=130)
# Last window reached. Current window (with length 80) would start with ID 21580, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=80; spacing=140)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=80; spacing=150)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_7_monitor_node_1_preamp_lpth_3-2_1_12.5GHz.dat (window length=80; spacing=160)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=80; spacing=10)
# Last window reached. Current window (with length 80) would start with ID 21530, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=80; spacing=20)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=80; spacing=30)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=80; spacing=40)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=80; spacing=50)
# Last window reached. Current window (with length 80) would start with ID 21550, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=80; spacing=60)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=80; spacing=70)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=80; spacing=80)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=80; spacing=90)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=80; spacing=100)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=80; spacing=110)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=80; spacing=120)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=80; spacing=130)
# Last window reached. Current window (with length 80) would start with ID 21580, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=80; spacing=140)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=80; spacing=150)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_2_1_50GHz.dat (window length=80; spacing=160)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=80; spacing=10)
# Last window reached. Current window (with length 80) would start with ID 21530, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=80; spacing=20)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=80; spacing=30)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=80; spacing=40)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=80; spacing=50)
# Last window reached. Current window (with length 80) would start with ID 21550, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=80; spacing=60)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=80; spacing=70)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=80; spacing=80)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=80; spacing=90)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=80; spacing=100)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=80; spacing=110)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=80; spacing=120)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=80; spacing=130)
# Last window reached. Current window (with length 80) would start with ID 21580, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=80; spacing=140)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=80; spacing=150)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-1_1_50GHz.dat (window length=80; spacing=160)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=80; spacing=10)
# Last window reached. Current window (with length 80) would start with ID 21530, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=80; spacing=20)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=80; spacing=30)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=80; spacing=40)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=80; spacing=50)
# Last window reached. Current window (with length 80) would start with ID 21550, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=80; spacing=60)
# Last window reached. Current window (with length 80) would start with ID 21540, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=80; spacing=70)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=80; spacing=80)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=80; spacing=90)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=80; spacing=100)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=80; spacing=110)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=80; spacing=120)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=80; spacing=130)
# Last window reached. Current window (with length 80) would start with ID 21580, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=80; spacing=140)
# Last window reached. Current window (with length 80) would start with ID 21560, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=80; spacing=150)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
#
# Creating windows dataset from file Scenario_8_monitor_node_1_preamp_lpth_3-2_1_50GHz.dat (window length=80; spacing=160)
# Last window reached. Current window (with length 80) would start with ID 21600, but last OSNR ID is 21599
